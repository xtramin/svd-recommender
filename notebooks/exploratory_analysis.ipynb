# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import plotly.graph_objects as go

# %config InlineBackend.figure_format = "retina"

# %%
column_names = ["user_id", "item_id", "rating", "timestamp"]

df = pd.read_csv(
    "/Users/ramin/.surprise_data/ml-100k/ml-100k/u.data", sep="\t", names=column_names
).drop(columns="timestamp")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 3 columns):
#  #   Column   Non-Null Count   Dtype
# ---  ------   --------------   -----
#  0   user_id  100000 non-null  int64
#  1   item_id  100000 non-null  int64
#  2   rating   100000 non-null  int64
# dtypes: int64(3)
# memory usage: 2.3 MB

# %%
df.describe().T
# Out:
#             count       mean         std  min    25%    50%    75%     max
# user_id  100000.0  462.48475  266.614420  1.0  254.0  447.0  682.0   943.0
# item_id  100000.0  425.53013  330.798356  1.0  175.0  322.0  631.0  1682.0
# rating   100000.0    3.52986    1.125674  1.0    3.0    4.0    4.0     5.0

# %%
df.isnull().sum()
# Out:
# user_id    0
# item_id    0
# rating     0
# dtype: int64

# %%
fig = go.Figure()
fig.add_trace(go.Histogram(x=df["rating"].values, histnorm="probability"))

fig.update_layout(
    height=600,
    yaxis=dict(range=[0, 0.4], dtick=0.1),
    title_text='Distribution of Ratings',
    xaxis_title_text='Rating',
    yaxis_title_text='Probability',
    bargap=0.2,
)

# %%
df.groupby("user_id").agg(count=("rating", "count")).sort_values(
    by="count", ascending=False
)
# Out:
#          count
# user_id
# 405        737
# 655        685
# 13         636
# 450        540
# 276        518
# ...        ...
# 685         20
# 475         20
# 36          20
# 732         20
# 596         20
#
# [943 rows x 1 columns]

# %%
df.groupby("item_id").agg(count=("rating", "count")).sort_values(
    by="count", ascending=False
)
# Out:
#          count
# item_id
# 50         583
# 258        509
# 100        508
# 181        507
# 294        485
# ...        ...
# 1576         1
# 1577         1
# 1348         1
# 1579         1
# 1682         1
#
# [1682 rows x 1 columns]
